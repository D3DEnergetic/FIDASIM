# %%
import numpy as np
from unyt import *
import matplotlib.pyplot as plt
import h5py
# %matplotlib notebook
from numpy.polynomial import chebyshev
import pandas as pd

# %%
n2= pd.read_csv('ec2.dat', names = ['E', 's', 'p'], sep = '    ')
# Out:
# /sw/python/anaconda-2021.11/lib/python3.9/site-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)

# %%
n3= pd.read_csv('ec3.dat', names = ['E', 's', 'p', 'd'], sep = '    ')
# Out:
# /sw/python/anaconda-2021.11/lib/python3.9/site-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)

# %%
plt.figure()
plt.plot(n3.E, n3.s*10**(-16))
plt.yscale('log')
plt.xscale('log')
plt.grid(which = 'both')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(n2.E, n2.s*10**(-16))
plt.yscale('log')
plt.xscale('log')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
 n1 = pd.read_csv('ec1.dat', names = ['E', 's'], sep = '    ')
# Out:
# /sw/python/anaconda-2021.11/lib/python3.9/site-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)

# %%
plt.figure()
plt.plot(n1.E, n1.s*10**(-16))
plt.yscale('log')
plt.xscale('log')
# Out:
# <img src="data:image/png;base64,..." width="640">
